# %%
import numpy as np
import math as mt
import time
from Parameter_Store_house import *
# Out:
# 100.0
# ['10', '20', '30', '40']
# interger_list [10.0]
# interger_list [10.0, 20.0]
# interger_list [10.0, 20.0, 30.0]
# interger_list [10.0, 20.0, 30.0, 40.0]
# array [10. 20. 30. 40.]
# <class 'numpy.ndarray'>

# %%
def numeric_converter(t):
    counter = 0

    while True:
        try:
            s=float(t)
            round(s,2)
            break
        except:
            print("Error\nInput not a numeric value")
            t = input("Input a numeric value\n")
            counter += 1
        if counter == 10:
            print("Errors made too many")
            break
    return s
        
mass= "20"
print(numeric_converter(mass))
# Out:
# Error
# Input not a numeric value
# 100.0

# %%
def arraying(t):
    l_a=[]
    values = t.strip().split(" ")
    print(values)
    for entities in values:
        integer_form=numeric_converter(entities)
        l_a.append(integer_form)
        print("interger_list",l_a)
    a = np.array(l_a)
    print("array",a)
    print(type(a))
    # f=numeric_converter(a)
    # print(f)

Mass = "10 20 30 40 "
arraying(Mass)

# %%
chemical= input("Chemical name")
print(chemical)
rate = input("Enter rate")
print(rate)
rate = numeric_converter(rate)
print(rate)
Required_input = input("How much do u need\n")
Required_input = numeric_converter(Required_input)
print(Required_input)
initial_ammount= input("Present quantity\n")
print(initial_ammount)
initial_ammount = numeric_converter(initial_ammount)
print(initial_ammount)
def supply_unit(add):
    print("Adding Chemical")
    global chemical, rate, Required_input, initial_ammount
    timer = 0
    # initial_ammount = input()
    # initial_ammount=numeric_converter(initial_ammount)
    while initial_ammount < Required_input and add :
        time.sleep(1)
        initial_ammount += rate
        timer += 1
        print(f"The current ammount of the liaquid in the tank after \n{timer} seconds \nis\n{initial_ammount}")
    return initial_ammount

print(supply_unit(True))
# Out:
# h
# 10
# 10.0
# 20.0
# 30
# 30.0
# Adding Chemical
# 30.0

# %%
chemical = input ( "Chemical Name")

def supply_unit():
    Required_ammount=numeric_converter(input("What do u need\n"))
    Initial
